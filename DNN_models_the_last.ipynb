# %% [markdown]
# <a href="https://colab.research.google.com/github/domshog/domshog/blob/master/DNN_models_the_last.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns # for plot visualization
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# import os
# print(os.listdir("../input"))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9e249cc-244e-448c-9833-06e93b13ca89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9e249cc-244e-448c-9833-06e93b13ca89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving book13.csv to book13.csv

# %%
weather_df = pd.read_csv('book13.csv', parse_dates=['date'])
weather_df.head()
# Out:
#         date     DNN-1     DNN-2  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0 2014-01-01  0.115229  0.179689  ...          NaN          NaN          NaN
# 1 2014-01-02  0.157700  0.203001  ...          NaN          NaN          NaN
# 2 2014-01-03  0.112242  0.173417  ...          NaN          NaN          NaN
# 3 2014-01-04  0.112536  0.173564  ...          NaN          NaN          NaN
# 4 2014-01-05  0.126093  0.176187  ...          NaN          NaN          NaN
#
# [5 rows x 17 columns]

# %%
monthly_df = weather_df.resample('M', on='date').mean()
monthly_df.head()
# Out:
#                DNN-1     DNN-2     DNN-3  ...  Unnamed: 14  Unnamed: 15  Unnamed: 16
# date                                      ...
# 2014-01-31  0.165021  0.209419  0.186071  ...          NaN          NaN          NaN
# 2014-02-28  0.545544  0.493283  0.537695  ...          NaN          NaN          NaN
# 2014-03-31  0.495660  0.448639  0.503821  ...          NaN          NaN          NaN
# 2014-04-30  0.657478  0.613819  0.649496  ...          NaN          NaN          NaN
# 2014-05-31  0.857173  0.824871  0.834665  ...          NaN          NaN          NaN
#
# [5 rows x 16 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
monthly_df.plot(figsize=(20, 12))

# %%
sns.plot(size=None , data=monthly_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-39b3f1ba2993> in <module>()
# ----> 1 sns.plot(size=None , data=monthly_df)
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
pip install ml_metrics
# Out:
# ...
#   Created wheel for ml-metrics: filename=ml_metrics-0.1.4-cp36-none-any.whl size=7850 sha256=4f26ecd1820cde8d6e97622f7670300223cdc2b97464aff42f882789ad020ece
#   Stored in directory: /root/.cache/pip/wheels/b3/61/2d/776be7b8a4f14c5db48c8e5451451cabc58dc6aa7ee3801163
# Successfully built ml-metrics
# ...

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import ml_metrics as metrics
from ml_metrics import rmse

# %%
mean_squared_error(monthly_df['test_data'], monthly_df['DNN-1']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-2']),mean_squared_error(monthly_df['test_data'], monthly_df['DNN-3']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-4']),mean_squared_error(monthly_df['test_data'], monthly_df['DNN-5']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-6']),mean_squared_error(monthly_df['test_data'], monthly_df['DNN-7']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-8']),mean_squared_error(monthly_df['test_data'], monthly_df['DNN-9']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-10']),mean_squared_error(monthly_df['test_data'], monthly_df['DNN-11']), mean_squared_error(monthly_df['test_data'], monthly_df['DNN-12'])
# Out:
# (0.010816925552032884,
#  0.011130272223039412,
#  0.010163630704334828,
#  0.007881636070707151,
#  0.00963398230266593,
#  0.009525854510157007,
#  0.01614139382904016,
#  0.012768952704971658,
#  0.01156726359303399,
#  0.009710137978601423,
#  0.01047583243901691,
#  0.010412395007180076)

# %%
rmse(monthly_df['test_data'], monthly_df['DNN-1']), rmse(monthly_df['test_data'], monthly_df['DNN-2']),rmse(monthly_df['test_data'], monthly_df['DNN-3']), rmse(monthly_df['test_data'], monthly_df['DNN-4']),rmse(monthly_df['test_data'], monthly_df['DNN-5']), rmse(monthly_df['test_data'], monthly_df['DNN-6']),rmse(monthly_df['test_data'], monthly_df['DNN-7']), rmse(monthly_df['test_data'], monthly_df['DNN-8']),rmse(monthly_df['test_data'], monthly_df['DNN-9']), rmse(monthly_df['test_data'], monthly_df['DNN-10']),rmse(monthly_df['test_data'], monthly_df['DNN-11']), rmse(monthly_df['test_data'], monthly_df['DNN-12'])
# Out:
# (0.10400444967419849,
#  0.1055001053224091,
#  0.10081483375146154,
#  0.08877857889551483,
#  0.09815285172966667,
#  0.09760048416968538,
#  0.1270487852324459,
#  0.1129997907297693,
#  0.10755121381478681,
#  0.09854003236553874,
#  0.10235151410221986,
#  0.10204114369792254)

# %%
mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-1']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-2']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-3']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-4']),mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-5']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-6']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-7']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-8']),mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-9']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-10']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-11']), mean_absolute_error(monthly_df['test_data'], monthly_df['DNN-12'])
# Out:
# (0.08312316065179846,
#  0.08994036993214925,
#  0.08608527690981176,
#  0.07143856130355215,
#  0.08430658380881328,
#  0.08010221533563104,
#  0.11635331914208268,
#  0.09845884956143748,
#  0.09148342410257936,
#  0.08022535039848304,
#  0.08621415567651687,
#  0.08369090045831407)

# %% [markdown]
# # **MBE (Mean bias error)**

# %%
[np.mean(monthly_df['DNN-1']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-2']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-3']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-4']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-5']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-6']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-7']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-8']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-9']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-10']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-11']-monthly_df['test_data']), 
 np.mean(monthly_df['DNN-12']-monthly_df['test_data'])]
# Out:
# [-0.004773286580472315,
#  -0.022777212540213726,
#  -0.0058623632042562575,
#  -0.004714405022548593,
#  -0.020018156440175364,
#  -0.022496385036885513,
#  -0.021122697300326385,
#  -0.01435716304763828,
#  0.020442075778782667,
#  -0.018054538834504526,
#  -0.010582212103577812,
#  -0.0035630005482782784]

# %% [markdown]
# # **Coefficient of Determination**

# %%
from sklearn.metrics import r2_score
[r2_score(monthly_df['test_data'], monthly_df['DNN-1']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-2']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-3']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-4']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-5']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-6']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-7']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-8']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-9']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-10']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-11']), 
 r2_score(monthly_df['test_data'], monthly_df['DNN-12'])]
# Out:
# [0.8032536157513492,
#  0.7975542306312122,
#  0.8151362342009798,
#  0.8566428703409217,
#  0.8247698780168835,
#  0.8267365876989078,
#  0.7064081788008334,
#  0.7677486765291583,
#  0.7896059026538473,
#  0.8233847012577161,
#  0.8094576740445486,
#  0.810611521806547]

# %% [markdown]
# # **Relative Root Mean Squared Error**

# %%
pip install TSErrors

# %%
import numpy as np
from TSErrors import FindErrors
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-1'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.20287975398542207

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-2'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.205797304637403

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-3'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.19665782313784802

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-4'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.17317890053665377

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-5'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.19146513898455322

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-6'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.19038764475205083

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-7'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.24783195692924076

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-8'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.2204268165013628

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-9'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.2097983679345461

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-10'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.19222040582553657

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-11'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.199655399996268

# %%
er = FindErrors(monthly_df['test_data'], monthly_df['DNN-12'])
er.relative_rmse()   # calculate Nash Sutcliff efficiency
# Out:
# 0.199049965599322
