# %% [markdown]
# <a href="https://colab.research.google.com/github/domshog/Projects/blob/master/Simple_Paraphrase_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Installing the PARROT Library

# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git

# %% [markdown]
# # 2. Importing the Libraries

# %%
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3. Reproducibility of the Text Paraphrasing

# %%
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %% [markdown]
# # 4. Load the Text Paraphrasing Model

# %%
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/913 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# ...

# %% [markdown]
# # 5. Input Text

# %%
phrases = ["Texting is the act of composing and sending electronic messages, typically consisting of alphabetic and numeric characters, between two or more users of mobile devices, laptops, or another type of compatible computer."]

# %% [markdown]
# # 6. Generating the Paraphrased Text

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  Texting is the act of composing and sending electronic messages, typically consisting of alphabetic and numeric characters, between two or more users of mobile devices, laptops, or another type of compatible computer.
# ----------------------------------------------------------------------------------------------------
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ('texting is the act of composing and sending electronic messages normally composed of alphabetic and numeric characters between two or more users of mobile devices laptops or another type of compatible computer', 25)
# ...
